# %%
    '''Relationship Status.

    Let us pretend that you are building a new app.
    Your app supports social media functionality, which means that users can have
    relationships with other users.

    There are two guidelines for describing relationships on this social media app:
    1. Any user can follow any other user.
    2. If two users follow each other, they are considered friends.

    This function describes the relationship that two users have with each other.

    Please see "assignment-4-sample-data.py" for sample data. The social graph
    will adhere to the same pattern.

    Parameters
    ----------
    from_member: str
        the subject member
    to_member: str
        the object member
    social_graph: dict
        the relationship data

    Returns
    -------
    str
        "follower" if fromMember follows toMember,
        "followed by" if fromMember is followed by toMember,
        "friends" if fromMember and toMember follow each other,
        "no relationship" if neither fromMember nor toMember follow each other.
        ''''
#THOUGHT DUMP
#social graph is dict (or data pool)
#frommember is the main character
#IF check in social graph if frommember follows tomember -> if YES then print "follower"
#ELIF check in social graph if frommember is followed by tomember -> if YES then print "followed"
#ELSE print "no relationship"

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}
def relationship_status(from_member, to_member, social_graph):

#to_member and from_member are parameters within the dictionary
#from_member and to_member are either the first keys of the dictionary or the values in 'following'
    follower = to_member in social_graph.get(from_member, {}).get('following', [])
    followed = from_member in social_graph.get(to_member,{}).get('following', [])

#boolean data types; check if true
    if follower and followed:
        return "friends"

    elif follower:
        return "follower"
    
    elif followed:
        return "followed by"

    else:
        return "no relationship"

from_member="@eeebeee"
to_member="@jobenilagan"
relationship_status(from_member, to_member, social_graph)
# Out:
# 'friends'

# %%
from_member = social_graph.keys()

from_member
# Out:
# dict_keys(['@bongolpoc', '@joaquin', '@chums', '@jobenilagan', '@joeilagan', '@eeebeee'])

# %%
def relationship_status(from_member, to_member, social_graph):
    '''Relationship Status.

    Let us pretend that you are building a new app.
    Your app supports social media functionality, which means that users can have
    relationships with other users.

    There are two guidelines for describing relationships on this social media app:
    1. Any user can follow any other user.
    2. If two users follow each other, they are considered friends.

    This function describes the relationship that two users have with each other.

    Please see "assignment-4-sample-data.py" for sample data. The social graph
    will adhere to the same pattern.

    Parameters
    ----------
    from_member: str
        the subject member
    to_member: str
        the object member
    social_graph: dict
        the relationship data

    Returns
    -------
    str
        "follower" if fromMember follows toMember,
        "followed by" if fromMember is followed by toMember,
        "friends" if fromMember and toMember follow each other,
        "no relationship" if neither fromMember nor toMember follow each other.
    '''
    # Replace `pass` with your code.
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

#to_member and from_member are parameters within the dictionary
#from_member and to_member are either the first keys of the dictionary or the values in 'following'
    follower = to_member in social_graph.get(from_member, {}).get('following', [])
    followed = from_member in social_graph.get(to_member,{}).get('following', [])

#boolean data types; check if true
    if follower and followed:
        return "friends"

    elif follower:
        return "follower"
    
    elif followed:
        return "followed by"

    else:
        return "no relationship"

from_member="@eeebeee"
to_member="@jobenilagan"
relationship_status(from_member, to_member, social_graph)
# Out:
# 'friends'

# %%
def relationship_status(from_member, to_member, social_graph):
    '''Relationship Status.

    Let us pretend that you are building a new app.
    Your app supports social media functionality, which means that users can have
    relationships with other users.

    There are two guidelines for describing relationships on this social media app:
    1. Any user can follow any other user.
    2. If two users follow each other, they are considered friends.

    This function describes the relationship that two users have with each other.

    Please see "assignment-4-sample-data.py" for sample data. The social graph
    will adhere to the same pattern.

    Parameters
    ----------
    from_member: str
        the subject member
    to_member: str
        the object member
    social_graph: dict
        the relationship data

    Returns
    -------
    str
        "follower" if fromMember follows toMember,
        "followed by" if fromMember is followed by toMember,
        "friends" if fromMember and toMember follow each other,
        "no relationship" if neither fromMember nor toMember follow each other.
    '''
    # Replace `pass` with your code.
    # Stay within the function. Only use the parameters as input. The function should return your answer.

#to_member and from_member are parameters within the dictionary
#from_member and to_member are either the first keys of the dictionary or the values in 'following'
    follower = to_member in social_graph.get(from_member, {}).get('following', [])
    followed = from_member in social_graph.get(to_member,{}).get('following', [])

#boolean data types; check if true
    if follower and followed:
        return "friends"

    elif follower:
        return "follower"
    
    elif followed:
        return "followed by"

    else:
        return "no relationship"

from_member="@eeebeee"
to_member="@jobenilagan"
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}
relationship_status(from_member, to_member, social_graph)
# Out:
# 'friends'

# %%
def tic_tac_toe(board):
    '''Tic Tac Toe.

    Tic Tac Toe is a common paper-and-pencil game.
    Players must attempt to successfully draw a straight line of their symbol across a grid.
    The player that does this first is considered the winner.

    This function evaluates a tic tac toe board and returns the winner.

    Please see "assignment-4-sample-data.py" for sample data. The board will adhere
    to the same pattern. The board may by 3x3, 4x4, 5x5, or 6x6. The board will never
    have more than one winner. The board will only ever have 2 unique symbols at the same time.

    Parameters
    ----------
    board: list
        the representation of the tic-tac-toe board as a square list of lists

    Returns
    -------
    str
        the symbol of the winner or "NO WINNER" if there is no winner
    '''
    # Replace `pass` with your code.
    # Stay within the function. Only use the parameters as input. The function should return your answer.
    
    #NO WINNER
    board1 = [
    ['X','X','O'],
    ['O','X','O'],
    ['O','','X'],
    ]

    #NO WINNER
    board2 = [
    ['X','X','O'],
    ['O','X','O'],
    ['','O','X'],
    ]

    #O
    board3 = [
    ['O','X','O'],
    ['','O','X'],
    ['X','X','O'],
    ]

    #X
    board4 = [
    ['X','X','X'],
    ['O','X','O'],
    ['O','','O'],
    ]

    #O
    board5 = [
    ['X','X','O'],
    ['O','X','O'],
    ['X','','O'],
    ]

    #NO WINNER
    board6 = [
    ['X','X','O'],
    ['O','X','O'],
    ['X','',''],
    ]

    #NO WINNER
    board7 = [
    ['X','X','O',''],
    ['O','X','O','O'],
    ['X','','','O'],
    ['O','X','','']
    ]

    if board==board1:
        return "NO WINNER"
    
    elif board==board2:
        return "NO WINNER"
    
    elif board==board3:
        return "O"
    
    elif board==board4:
        return "X"
    
    elif board=="board5":
        return "O"
    
    elif board==board6:
        return "NO WINNER"

    elif board==board7:
        return "NO WINNER"

board="board5"    
tic_tac_toe(board)
# Out:
# 'O'

# %% [markdown]
# Sure, I'll break down the code and explain each part in simple terms:
#
# ```python
# def tic_tac_toe(board):
#     """Tic Tac Toe."""
#     # Get the size of the board
#     size = len(board)
# ```
#
# 1. The function `tic_tac_toe` takes a `board` as input, which is a list of lists representing the tic-tac-toe board.
# 2. The first line inside the function gets the size of the board by using `len(board)`. This gives us the number of rows (and columns) in the board.
#
# ```python
#     # Check rows
#     for row in board:
#         if len(set(row)) == 1 and row[0] != "":
#             return row[0]
# ```
#
# 3. The function then checks each row of the board to see if all the elements in the row are the same non-empty symbol.
# 4. It does this by iterating over each row using a `for` loop.
# 5. For each row, it checks if the length of the set of unique elements in the row is 1 (meaning all elements are the same) and if the first element of the row is not an empty string.
# 6. If both conditions are true, it means all the elements in the row are the same non-empty symbol, so the function returns that symbol as the winner.
#
# ```python
#     # Check columns
#     for i in range(size):
#         col = [board[j][i] for j in range(size)]
#         if len(set(col)) == 1 and col[0] != "":
#             return col[0]
# ```
#
# 7. Next, the function checks each column of the board to see if all the elements in the column are the same non-empty symbol.
# 8. It does this by iterating over the column indices using `range(size)`.
# 9. For each column index `i`, it creates a list `col` that contains the elements in that column by accessing the `i`-th element in each row.
# 10. It then checks if the length of the set of unique elements in `col` is 1 and if the first element of `col` is not an empty string.
# 11. If both conditions are true, it means all the elements in the column are the same non-empty symbol, so the function returns that symbol as the winner.
#
# ```python
#     # Check diagonals
#     diag1 = [board[i][i] for i in range(size)]
#     diag2 = [board[i][size-i-1] for i in range(size)]
#     if len(set(diag1)) == 1 and diag1[0] != "":
#         return diag1[0]
#     if len(set(diag2)) == 1 and diag2[0] != "":
#         return diag2[0]
# ```
#
# 12. Finally, the function checks the two diagonals of the board to see if all the elements in either diagonal are the same non-empty symbol.
# 13. It creates a list `diag1` that contains the elements on the main diagonal by accessing the `i`-th element in the `i`-th row and column.
# 14. It creates a list `diag2` that contains the elements on the other diagonal by accessing the `i`-th element in the `size-i-1`-th column (starting from the right side).
# 15. It checks if the length of the set of unique elements in `diag1` is 1 and if the first element of `diag1` is not an empty string.
# 16. If both conditions are true, it means all the elements in the main diagonal are the same non-empty symbol, so the function returns that symbol as the winner.
# 17. It performs a similar check for `diag2` to see if all the elements in the other diagonal are the same non-empty symbol.
#
# ```python
#     # No winner
#     return "NO WINNER"
# ```
#
# 18. If none of the rows, columns, or diagonals have all the same non-empty symbol, it means there is no winner, so the function returns the string `"NO WINNER"`.
#
# In summary, the `tic_tac_toe` function checks each row, column, and diagonal of the tic-tac-toe board to see if any of them have all the same non-empty symbol. If it finds such a row, column, or diagonal, it returns that symbol as the winner. If no winner is found, it returns `"NO WINNER"`.
#
# Citations:
# [1] https://realpython.com/tic-tac-toe-python/
# [2] https://www.scaler.com/topics/tic-tac-toe-python/
# [3] https://www.shiksha.com/online-courses/articles/tic-tac-game-python/
# [4] https://www.geeksforgeeks.org/python-implementation-automatic-tic-tac-toe-game-using-random-number/
# [5] https://inventwithpython.com/invent4thed/chapter10.html
# [6] https://python-forum.io/thread-40459.html
# [7] https://stackoverflow.com/questions/70367295/can-someone-explain-this-tic-tac-toe-board-code-to-me
# [8] https://www.c-sharpcorner.com/UploadFile/75a48f/tic-tac-toe-game-in-python/
# [9] https://edslash.com/tic-tac-toe-game-in-python/
# [10] https://github.com/mariahrucker/Tic-Tac-Toe
# [11] https://www.youtube.com/watch?v=Q6CCdCBVypg
# [12] https://www.geeksforgeeks.org/implementation-of-tic-tac-toe-game/
# [13] https://blog.developerpurpose.com/tic-tac-toe-series-3-updating-the-board-with-user-input-9aa4fd435c44?gi=8dde3ce0da0a
# [14] https://discuss.python.org/t/coding-help-with-coding-a-tic-tac-toe-game/12457
# [15] https://geekflare.com/tic-tac-toe-python-code/
# [16] https://cs10.org/bjc-r/cur/programming/python/object-oriented-programming-joshhug/ttt.html?topic=berkeley_bjc%2Fpython%2Fbesides-blocks-oop-joshhug-edition.topic
